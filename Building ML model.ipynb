# %% [markdown]
# <a href="https://colab.research.google.com/github/vaseem-20/node/blob/main/Building%20ML%20model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#data exploration

# %%
df.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#null value conunt

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df = pd.read_csv("/content/house_price.csv")
df
# Out:
#     SquareFootage   Price
# 0            1500  250000
# 1            1800  320000
# 2            1700  280000
# 3            1600  220000
# 4            1900  340000
# 5            2000  400000
# 6            2100  370000
# 7            1750  290000
# 8            1850  310000
# 9            1950  330000
# 10           1400  210000
# 11           1650  240000
# 12           1550  260000
# 13           1800  315000
# 14           2050  390000
# 15           2200  420000
# 16           2300  450000
# 17           2400  460000
# 18           2500  500000
# 19           2600  480000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SquareFootage  20 non-null     int64
#  1   Price          20 non-null     int64
# dtypes: int64(2)
# memory usage: 452.0 bytes

# %%
df.columns
# Out:
# Index(['SquareFootage', 'Price'], dtype='object')

# %%
df.isnull()
# Out:
#     SquareFootage  Price
# 0           False  False
# 1           False  False
# 2           False  False
# 3           False  False
# 4           False  False
# 5           False  False
# 6           False  False
# 7           False  False
# 8           False  False
# 9           False  False
# 10          False  False
# 11          False  False
# 12          False  False
# 13          False  False
# 14          False  False
# 15          False  False
# 16          False  False
# 17          False  False
# 18          False  False
# 19          False  False

# %%
df.isnull().sum()
# Out:
# SquareFootage    0
# Price            0
# dtype: int64

# %%
df.describe()
# Out:
#        SquareFootage          Price
# count      20.000000      20.000000
# mean     1930.000000  341750.000000
# std       338.495122   88544.889002
# min      1400.000000  210000.000000
# 25%      1687.500000  275000.000000
# 50%      1875.000000  325000.000000
# 75%      2125.000000  405000.000000
# max      2600.000000  500000.000000

# %%
df['SquareFootage']
# Out:
# 0     1500
# 1     1800
# 2     1700
# 3     1600
# 4     1900
# 5     2000
# 6     2100
# 7     1750
# 8     1850
# 9     1950
# 10    1400
# 11    1650
# 12    1550
# 13    1800
# 14    2050
# 15    2200
# 16    2300
# 17    2400
# 18    2500
# 19    2600
# Name: SquareFootage, dtype: int64

# %%
df[['SquareFootage']]
# Out:
#     SquareFootage
# 0            1500
# 1            1800
# 2            1700
# 3            1600
# 4            1900
# 5            2000
# 6            2100
# 7            1750
# 8            1850
# 9            1950
# 10           1400
# 11           1650
# 12           1550
# 13           1800
# 14           2050
# 15           2200
# 16           2300
# 17           2400
# 18           2500
# 19           2600

# %%
type(df[['SquareFootage']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['Price']
# Out:
# 0     250000
# 1     320000
# 2     280000
# 3     220000
# 4     340000
# 5     400000
# 6     370000
# 7     290000
# 8     310000
# 9     330000
# 10    210000
# 11    240000
# 12    260000
# 13    315000
# 14    390000
# 15    420000
# 16    450000
# 17    460000
# 18    500000
# 19    480000
# Name: Price, dtype: int64

# %%
#define dependent(y) and independent(x) variables
#df['SquareFootage'] ---- independent variable
#df['price']---dependent variable

# %%
x = df[['SquareFootage']]

# %%
y = df['Price']
y
# Out:
# 0     250000
# 1     320000
# 2     280000
# 3     220000
# 4     340000
# 5     400000
# 6     370000
# 7     290000
# 8     310000
# 9     330000
# 10    210000
# 11    240000
# 12    260000
# 13    315000
# 14    390000
# 15    420000
# 16    450000
# 17    460000
# 18    500000
# 19    480000
# Name: Price, dtype: int64

# %%
#split data
# training and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=4)

# %%
x_train,x_test,y_train,y_test
# Out:
# (    SquareFootage
#  13           1800
#  4            1900
#  0            1500
#  17           2400
#  12           1550
#  11           1650
#  15           2200
#  10           1400
#  9            1950
#  2            1700
#  16           2300
#  7            1750
#  8            1850
#  1            1800
#  5            2000
#  14           2050,
#      SquareFootage
#  19           2600
#  3            1600
#  18           2500
#  6            2100,
#  13    315000
#  4     340000
#  0     250000
#  17    460000
#  12    260000
#  11    240000
#  15    420000
#  10    210000
#  9     330000
#  2     280000
#  16    450000
#  7     290000
#  8     310000
#  1     320000
#  5     400000
#  14    390000
#  Name: Price, dtype: int64,
#  19    480000
#  3     220000
#  18    500000
#  6     370000
#  Name: Price, dtype: int64)

# %%
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#     SquareFootage
# 13           1800
# 4            1900
# 0            1500
# 17           2400
# 12           1550
# 11           1650
# 15           2200
# 10           1400
# 9            1950
# 2            1700
# 16           2300
# 7            1750
# 8            1850
# 1            1800
# 5            2000
# 14           2050
#     SquareFootage
# 19           2600
# 3            1600
# 18           2500
# 6            2100
# 13    315000
# 4     340000
# 0     250000
# 17    460000
# 12    260000
# 11    240000
# 15    420000
# 10    210000
# 9     330000
# 2     280000
# 16    450000
# 7     290000
# 8     310000
# 1     320000
# 5     400000
# 14    390000
# Name: Price, dtype: int64
# 19    480000
# 3     220000
# 18    500000
# 6     370000
# Name: Price, dtype: int64

# %%
#training --16 records to model learn

#test --4 testing to model performence

# %%
print(x_train.shape,y_train.shape)

print(x_test.shape,y_test.shape)
# Out:
# (16, 1) (16,)
# (4, 1) (4,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
dir(model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
# ...

# %%
help(model.fit)
# Out:
# Help on method fit in module sklearn.linear_model._base:
#
# fit(X, y, sample_weight=None) method of sklearn.linear_model._base.LinearRegression instance
#     Fit linear model.
#
#     Parameters
#     ----------
#     X : {array-like, sparse matrix} of shape (n_samples, n_features)
#         Training data.
#
#     y : array-like of shape (n_samples,) or (n_samples, n_targets)
#         Target values. Will be cast to X's dtype if necessary.
#
#     sample_weight : array-like of shape (n_samples,), default=None
#         Individual weights for each sample.
#
#         .. versionadded:: 0.17
#            parameter *sample_weight* support to LinearRegression.
#
#     Returns
#     -------
#     self : object
#         Fitted Estimator.

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test
type(y_test)
# Out:
# pandas.core.series.Series

# %%
actual_price = y_test.tolist()
actual_price
# Out:
# [480000, 220000, 500000, 370000]

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([523216.71907757, 259956.76100629, 496890.72327044, 391586.74004193])

# %%
df = pd.DataFrame(
    {
        'Actual_price':actual_price,
        'predicted_price':y_pred.tolist()
    }
)
df
# Out:
#    Actual_price  predicted_price
# 0        480000    523216.719078
# 1        220000    259956.761006
# 2        500000    496890.723270
# 3        370000    391586.740042

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mae = mean_absolute_error(y_test,y_pred)
mae
# Out:
# 26967.37421383646

# %%
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 984970626.3404863

# %%
R2_score = r2_score(y_test,y_pred)
R2_score
# Out:
# 0.9203661949396271

# %%
import numpy as np

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(31384.241688154365)
